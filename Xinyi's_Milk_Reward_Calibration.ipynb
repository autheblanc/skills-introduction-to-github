# %% [markdown]
# <a href="https://colab.research.google.com/github/autheblanc/skills-introduction-to-github/blob/create-my-first-branch/Xinyi's_Milk_Reward_Calibration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
rig_2 = {'x': [100,100,200,200,300,300,400,400], 'y': [15.2,15.5,30.7,28.5,47.92,46.02,64.94,63.34]}
rig_3 = {'x': [100,100,100,200,300,300,400,400], 'y': [13.28,14.74,29.88,29.1,44.38,46.44,60.78,58.9]}
rig_4 = {'x': [100,100,100,200,300,300,400,400], 'y': [9.4,8.74,13.46,16.98,18.96,19.92,23.98,27.38]}
rig_5 = {'x': [100,100,200,200,300,300,400,400], 'y': [5.36,12.92,9.26,8.82,15.5,13.76,17.4,19.22]}
rig_6 = {'x': [100,100,200,200,300,300,400,400], 'y': [9.26,12.7,18.3,18.62,25.44,26.06,30.14,32.72]}
rig_7 = {'x': [100,100,100,200,300,300,400,400], 'y': [14.3,16.16,33.18,33.9,50.6,50.34,67.06,64.74]}

# Plot each group with a unique style
plt.plot(rig_2['x'], rig_2['y'], label="Rig 2", linestyle='-', marker='o')
plt.plot(rig_3['x'], rig_3['y'], label="Rig 3", linestyle='--', marker='s')
plt.plot(rig_4['x'], rig_4['y'], label="Rig 4", linestyle='-.', marker='^')
plt.plot(rig_5['x'], rig_5['y'], label="Rig 5", linestyle='-', marker='o')
plt.plot(rig_6['x'], rig_6['y'], label="Rig 6", linestyle='--', marker='s')
plt.plot(rig_7['x'], rig_7['y'], label="Rig 7", linestyle='-.', marker='^')

# Add labels and legend
plt.xlabel('Duration(ms)')
plt.ylabel('Weight of 1 push (microlitre)')
plt.title('Milk Reward Calibration of 6 Rigs')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
rig_2 = {'x': [100,100,200,200,300,300,400,400], 'y': [15.2,15.5,30.7,28.5,47.92,46.02,64.94,63.34]}
rig_3 = {'x': [100,100,100,200,300,300,400,400], 'y': [13.28,14.74,29.88,29.1,44.38,46.44,60.78,58.9]}
rig_4 = {'x': [100,100,100,200,300,300,400,400], 'y': [9.4,8.74,13.46,16.98,18.96,19.92,23.98,27.38]}
rig_5 = {'x': [100,100,200,200,300,300,400,400], 'y': [5.36,12.92,9.26,8.82,15.5,13.76,17.4,19.22]}
rig_6 = {'x': [100,100,200,200,300,300,400,400], 'y': [9.26,12.7,18.3,18.62,25.44,26.06,30.14,32.72]}
rig_7 = {'x': [100,100,100,200,300,300,400,400], 'y': [14.3,16.16,33.18,33.9,50.6,50.34,67.06,64.74]}

rigs = [rig_2, rig_3, rig_4,rig_5,rig_6,rig_7]

# Plot each group with a unique style
for rig_i in rigs:
  plt.scatter(rig_i['x'], rig_i['y'])

# Add labels and legend
plt.xlabel('Duration(ms)')
plt.ylabel('Weight of 1 push (microlitre)')
plt.title('Milk Reward Calibration of 6 Rigs')


# Show the plot
plt.show()

# %%
import statsmodels.api as sm
import numpy as np

for rig_i in rigs:
  mi = sm.OLS.from_formula('y ~ x -1', data= rig_i)
  results = mi.fit()
  print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                              6568.
# Date:                Sun, 01 Dec 2024   Prob (F-statistic):                    1.15e-11
# Time:                        02:38:31   Log-Likelihood:                         -14.082
# No. Observations:                   8   AIC:                                      30.16
# Df Residuals:                       7   BIC:                                      30.24
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
weight_pred_2= 0.1573*np.array(rig_2['x'])

plt.scatter(rig_2['x'],rig_2['y'],color='blue')
plt.plot(rig_2['x'],weight_pred_2,color='red')
plt.title('Regression model of Rig 2')
plt.xlabel('Duration(ms')
plt.ylabel('Weight of 1 push(microlitre)')
plt.legend(['duration/ observed weight', 'duration/predicted weight'], loc='best', facecolor='white')
plt.box(False)
plt.xlim(0,450)
plt.ylim(0,70)
plt.annotate('Regression Slope=0.1573',xy=(300,20))
plt.show()

# %%
weight_pred_3=0.1522*np.array(rig_3['x'])

plt.scatter(rig_3['x'],rig_3['y'],color='blue')
plt.plot(rig_3['x'],weight_pred_3,color='red')
plt.title('Regression model of Rig 3')
plt.xlabel('Duration(ms')
plt.ylabel('Weight of 1 push(microlitre)')
plt.legend(['duration/ observed weight', 'duration/predicted weight'], loc='best', facecolor='white')
plt.box(False)
plt.annotate('Regression Slope=0.1522',xy=(300,20))
plt.show()

# %%
weight_pred_4=0.068*np.array(rig_4['x'])

plt.scatter(rig_4['x'],rig_4['y'],color='blue')
plt.plot(rig_4['x'],weight_pred_4,color='red')
plt.title('Regression model of Rig 4')
plt.xlabel('Duration(ms')
plt.ylabel('Weight of 1 push(microlitre)')
plt.legend(['duration/ observed weight', 'duration/predicted weight'], loc='best', facecolor='white')
plt.box(False)
plt.annotate('Regression Slope=0.068',xy=(300,15))
plt.show()

# %%
weight_pred_5=0.0481*np.array(rig_5['x'])

plt.scatter(rig_5['x'],rig_5['y'],color='blue')
plt.plot(rig_5['x'],weight_pred_5,color='red')
plt.title('Regression model of Rig 5')
plt.xlabel('Duration(ms')
plt.ylabel('Weight of 1 push(microlitre)')
plt.legend(['duration/ observed weight', 'duration/predicted weight'], loc='best', facecolor='white')
plt.box(False)
plt.annotate('Regression Slope=0.0481',xy=(300,8))
plt.show()

# %%
weight_pred_6=0.0836*np.array(rig_6['x'])

plt.scatter(rig_6['x'],rig_6['y'],color='blue')
plt.plot(rig_6['x'],weight_pred_6,color='red')
plt.title('Regression model of Rig 6')
plt.xlabel('Duration(ms')
plt.ylabel('Weight of 1 push(microlitre)')
plt.legend(['duration/ observed weight', 'duration/predicted weight'], loc='best', facecolor='white')
plt.box(False)
plt.annotate('Regression Slope=0.0836',xy=(300,15))
plt.show()

# %%
weight_pred_7=0.1687*np.array(rig_7['x'])

plt.scatter(rig_7['x'],rig_7['y'],color='blue')
plt.plot(rig_7['x'],weight_pred_7,color='red')
plt.title('Regression model of Rig 7')
plt.xlabel('Duration(ms')
plt.ylabel('Weight of 1 push(microlitre)')
plt.legend(['duration/ observed weight', 'duration/predicted weight'], loc='best', facecolor='white')
plt.box(False)
plt.annotate('Regression Slope=0.1687',xy=(300,20))
plt.show()

# %%
plt.scatter(rig_2['x'],rig_2['y'],color='blue')
plt.plot(rig_2['x'],weight_pred_2,color='blue')

plt.scatter(rig_3['x'],rig_3['y'],color='red')
plt.plot(rig_3['x'],weight_pred_3,color='red')

plt.scatter(rig_4['x'],rig_4['y'],color='green')
plt.plot(rig_4['x'],weight_pred_4,color='green')

plt.scatter(rig_5['x'],rig_5['y'],color='yellow')
plt.plot(rig_5['x'],weight_pred_5,color='yellow')

plt.scatter(rig_6['x'],rig_6['y'],color='purple')
plt.plot(rig_6['x'],weight_pred_6,color='purple')

plt.scatter(rig_7['x'],rig_7['y'],color='brown')
plt.plot(rig_7['x'],weight_pred_7,color='brown')

plt.title('Regression model of 6 Rigs')
plt.xlabel('Duration(ms')
plt.ylabel('Weight of 1 push(microlitre)')
plt.legend(['duration/ observed weight', 'duration/predicted weight'], loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
weight_pred= (weight_pred_2,weight_pred_3 ,weight_pred_4, weight_pred_5,weight_pred_6,weight_pred_7)

for weight_pred_i in weight_pred:
  for rig_i in rigs:
    plt.scatter(rig_i['x'],rig_i['y'])

    plt.plot(rig_i['x'], weight_pred_i)

plt.title('Regression model of 6 Rigs')
plt.xlabel('Duration(ms)')
plt.ylabel('Weight of 1 push(microlitre)')
plt.legend(['duration/ observed weight', 'duration/predicted weight'], loc='best', facecolor='white')
plt.box(False)
plt.show()
